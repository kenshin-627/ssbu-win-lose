# %%
from pynput import mouse
import os
import cv2
import time
import pyautogui
import numpy as np
import datetime
from PIL import Image
# import ctypes
# PROCESS_PER_MONITOR_DPI_AWARE = 2
# ctypes.windll.shcore.SetProcessDpiAwareness(PROCESS_PER_MONITOR_DPI_AWARE)

left_up_x, left_up_y, right_down_x, right_down_y = [0,0,0,0]
num_press = 0

def main():
    # スクリーンショットの範囲を決定する
    left, up, width, height = decide_region()
    # スクリーンショット保存用ディレクトリを作成
    os.makedirs("Screenshot", exist_ok=True)
    # リサイズ後の画像サイズ
    dsize_w = 1024
    dsize_h = 576
    
    # テンプレートマッチング用の画像作る
    gameset_gray = cv2.resize(cv2.imread("Image/gameset.png", cv2.IMREAD_GRAYSCALE), dsize=(dsize_w, dsize_h))
    gameset_gray = gameset_gray[int(dsize_h/10):int(-dsize_h/10*3), int(dsize_w/5):int(-dsize_w/5)]
#     cv2.imwrite("Image/gameset_gray.png", gameset_gray)
    
    st = time.time()
    # 範囲の指定が終わったら1秒毎にスクリーンショットを撮る
    while True:
        try:
#             time.sleep(0.1)
            print(time.time()-st)
            st = time.time()
            # 指定した範囲でスクリーンショットを撮影
            im = pyautogui.screenshot(region=(left, up, width, height))
#             im = Image.open("Image/before.png")
            # スクリーンショットをとった時間を記録
            ss_time = datetime.datetime.now().strftime("%y%m%d%H%M%S")
            path = "Screenshot/" + ss_time
            # 撮影したスクリーンショットをグレースケールに変換
            im_gray = im.convert("L")
            # OpenCVで扱えるようにImage型からndarrayに変換
            im_gray = np.array(im_gray)
            # 画像をリサイズ
            im_resize = cv2.resize(im_gray, dsize=(dsize_w, dsize_h))
            
            # このフレームが対戦終了タイミングかどうか
            if is_finish(im_resize, gameset_gray):
                # スクリーンショットを保存
                cv2.imwrite(f"{path}_finish.png", cv2.cvtColor(np.array(im), cv2.COLOR_RGB2BGR))
                print("対戦終了")
                # 5秒ストップして次のスクリーンショットへ
                time.sleep(5)
                continue
            
            # Canny法でエッジを検出
            im_edges = cv2.Canny(im_resize, 130, 400, L2gradient=True)
            # Hough変換で直線を検出
            im_lines = cv2.HoughLines(im_edges, rho=1, theta=np.pi/180, threshold=200)
            # 直線が検出されたときだけ，このフレームが対戦開始タイミングかどうかを判定する
            if not im_lines is None:
                # このフレームが対戦開始タイミングかどうか
                if is_start(im_lines, dsize_h):
                    # スクリーンショットを保存
                    # 画像を保存するパスは "Screenshot/年月日時分秒.png"
                    cv2.imwrite(f"{path}_start.png", cv2.cvtColor(np.array(im), cv2.COLOR_RGB2BGR))
                    print("対戦開始")
                    # 5秒ストップして次のスクリーンショット
                    time.sleep(5)
                    continue
            # 実験中は繰り返し一回で終わり
#             break
        # プログラムが停止されたら終わり
        except KeyboardInterrupt:
            break
            
    print("end")
    
# スクリーンショット範囲の左上と右下をクリックで決定する
def decide_region():
    # マウスのクリックを検知(クリック2回目が左上，3回目が右下でスクショ範囲を指定)
    with mouse.Listener(on_click=on_click) as listener:
        listener.join()
    # スクリーンショット範囲の計算(2倍したらいい理由は謎)
    left = left_up_x*2
    up = left_up_y*2
    width = (right_down_x-left_up_x)*2
    height = (right_down_y-left_up_y)*2
    return left, up, width, height

# マウスをクリックしたときの処理
def on_click(x, y, button, pressed):
    global left_up_x, left_up_y, right_down_x, right_down_y, num_press
    if pressed:
        # 1回目のクリックはウィンドウの切り替え用で何もしない
        if num_press == 0:
            num_press = 1
        # 2回目のクリックはスクリーンショットを撮る範囲の左上を指定
        elif num_press == 1:
            num_press = 2
            left_up_x, left_up_y = x, y
            return (x, y)
        # 3回目のクリックはスクリーンショットを撮る範囲の右下を指定して終了
        else:
            right_down_x, right_down_y = x, y
            return False

# テンプレートマッチング用の画像作る
def make_template_mask(template):
    # テンプレートのグレースケール画像
    template_gray = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)
    # テンプレートのマスク画像(閾値100で二値化)
    _, template_mask = cv2.threshold(template_gray, 100, 255, cv2.THRESH_BINARY)
    return template_gray, template_mask
        
# 引数で与えられた画像が対戦終了のタイミングならTrue
def is_finish(im_gray, gameset_gray):
    res = cv2.matchTemplate(im_gray, gameset_gray, cv2.TM_CCOEFF_NORMED)
    _, max_val, _, _ = cv2.minMaxLoc(res)
    is_fin = True if max_val > 0.4 else False
    return is_fin

# 引数で与えられた画像が対戦開始のタイミングならTrue
def is_start(im_lines, dsize_h, error=10**-2):
    # いい感じの直線の数
    line_count = 0
    # 画面の上の方か判断する閾値
    threshold = dsize_h*0.2
    # いい感じの直線の角度
    rad = 1.5358897
    for line in im_lines:
        line = line[0]
        # 直線が画面の上の方かどうか(下の方なら次の線)
        if line[0] > threshold:
            continue
        # いい感じ角度の直線なら
        if np.isclose(line[1], rad):
            line_count += 1
            # 2本あれば対戦開始のタイミング
            if line_count == 2:
                return True
    return False

# Hough変換で求めたθとρをもとに直線を引く
def draw_line(im, theta, rho):
    h, w = im.shape[:2]
    # 直線が垂直のとき
    if np.isclose(np.sin(theta), 0):
        x1, y1 = rho, 0
        x2, y2 = rho, h
    # 直線が垂直じゃないとき
    else:
        # 直線の式を式変形すればcalc_yの式がもとまる．
        calc_y = lambda x: rho / np.sin(theta) - x * np.cos(theta) / np.sin(theta)
        x1, y1 = 0, calc_y(0)
        x2, y2 = w, calc_y(w)
    x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])
    # 直線を描画 (imにアルファチャンネルがあると黒い線分しか引かれなくなる)
    cv2.line(im, (x1, y1), (x2, y2), (0, 255, 0), 2)

if __name__ == "__main__":
    main()
# Out:
# 3.0994415283203125e-06
# 0.933696985244751
# 0.7800807952880859
# 0.7876701354980469
# 0.8030383586883545
# 0.8105728626251221
# 0.8263280391693115
# 0.8098139762878418
# 0.8122920989990234
# 0.7790050506591797
# 0.8315632343292236
# 0.7937939167022705
# 0.806035041809082
# 0.794349193572998
# 0.34855175018310547
# 0.3675880432128906
# 0.36811304092407227
# 0.5345680713653564
# 0.7502949237823486
# 0.8131639957427979
# 0.7837271690368652
# 0.8187859058380127
# 0.788776159286499
# 0.7757158279418945
# 0.7711200714111328
# 0.34993600845336914
# 0.3485581874847412
# 0.3448300361633301
# 0.8534631729125977
# 0.8476431369781494
# 0.8627440929412842
# 0.8298521041870117
# 0.8505027294158936
# 0.8674771785736084
# 0.8696010112762451
# 0.8776187896728516
# 0.8856239318847656
# 0.8482260704040527
# 0.8570659160614014
# 0.865760087966919
# 0.8722832202911377
# 0.8645739555358887
# 0.817706823348999
# 0.8339829444885254
# 0.8719489574432373
# 0.7712912559509277
# 0.36954307556152344
# 0.3604590892791748
# 0.3604891300201416
# 0.36011695861816406
# 0.34986209869384766
# 0.3455820083618164
# 0.34761810302734375
# 0.34976887702941895
# 0.35144996643066406
# 0.4386630058288574
# 0.3462400436401367
# 0.5333456993103027
# 0.5013940334320068
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 165
#     162     cv2.line(im, (x1, y1), (x2, y2), (0, 255, 0), 2)
#     164 if __name__ == "__main__":
# --> 165     main()
#
# Cell In[8], line 66, in main()
#      63 # 直線が検出されたときだけ，このフレームが対戦開始タイミングかどうかを判定する
#      64 if not im_lines is None:
#      65     # このフレームが対戦開始タイミングかどうか
# ---> 66     if is_start(im_lines, dsize_h):
#      67         # スクリーンショットを保存
#      68         # 画像を保存するパスは "Screenshot/年月日時分秒.png"
#      69         cv2.imwrite(f"{path}_start.png", cv2.cvtColor(np.array(im), cv2.COLOR_RGB2BGR))
#      70         print("対戦開始")
#
# Cell In[8], line 141, in is_start(im_lines, dsize_h, error)
#     139 # いい感じ角度の直線なら
#     140 if np.isclose(line[1], rad):
# --> 141     count += 1
#     142     # 2本あれば対戦開始のタイミング
#     143     if count == 2:
#
# UnboundLocalError: local variable 'count' referenced before assignment

# %%
[[[ 82.          1.5358897]]

 [[100.          1.5358897]]]
